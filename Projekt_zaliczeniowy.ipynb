# %%
import pandas as pd
pd
# Out:
# <module 'pandas' from '/usr/local/lib/python3.8/dist-packages/pandas/__init__.py'>

# %%
df = pd.read_csv("/content/projekt/szczesna.csv")

# %%
df
# Out:
#      coordinates                      created_at  \
# 0            NaN  Tue Jun 01 05:26:49 +0000 2021
# 1            NaN  Tue Jun 01 04:15:56 +0000 2021
# 2            NaN  Tue Jun 01 04:47:19 +0000 2021
# 3            NaN  Tue Jun 01 05:47:47 +0000 2021
# 4            NaN  Tue Jun 01 05:03:08 +0000 2021
# ...          ...                             ...
# 5098         NaN  Fri Jun 04 15:44:32 +0000 2021
# 5099         NaN  Fri Jun 04 15:39:10 +0000 2021
# 5100         NaN  Fri Jun 04 15:41:51 +0000 2021
# 5101         NaN  Fri Jun 04 15:42:02 +0000 2021
# 5102         NaN  Fri Jun 04 15:43:33 +0000 2021
#
#                            hashtags  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4     WspieramyRodziny DzieńDziecka
# ...                             ...
# 5098                            NaN
# 5099                            NaN
# 5100                            NaN
# ...

# %%
#Część 1
df["created_at"] = [row.replace("Mon", "Poniedziałek").replace("Tue", "Wtorek").replace("Wed", "Środa").replace("Thu", "Czwartek").replace("Fri", "Piątek").replace("Sat", "Sobota").replace("Sun", "Niedziela") for row in df["created_at"]]

# %%
df
# Out:
#      coordinates                         created_at  \
# 0            NaN  Wtorek Jun 01 05:26:49 +0000 2021
# 1            NaN  Wtorek Jun 01 04:15:56 +0000 2021
# 2            NaN  Wtorek Jun 01 04:47:19 +0000 2021
# 3            NaN  Wtorek Jun 01 05:47:47 +0000 2021
# 4            NaN  Wtorek Jun 01 05:03:08 +0000 2021
# ...          ...                                ...
# 5098         NaN  Piątek Jun 04 15:44:32 +0000 2021
# 5099         NaN  Piątek Jun 04 15:39:10 +0000 2021
# 5100         NaN  Piątek Jun 04 15:41:51 +0000 2021
# 5101         NaN  Piątek Jun 04 15:42:02 +0000 2021
# 5102         NaN  Piątek Jun 04 15:43:33 +0000 2021
#
#                            hashtags  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4     WspieramyRodziny DzieńDziecka
# ...                             ...
# 5098                            NaN
# 5099                            NaN
# ...

# %%
df["user_created_at"] = [row.replace("Jan", "01").replace("Feb", "02").replace("Mar", "03").replace("Apr", "04").replace("May", "05").replace("Jun", "06").replace("Jul", "07").replace("Aug", "08").replace("Sep", "09").replace("Oct", "10").replace("Nov", "11").replace("Dec", "12") for row in df["user_created_at"]]

# %%
df
# Out:
#      coordinates                         created_at  \
# 0            NaN  Wtorek Jun 01 05:26:49 +0000 2021
# 1            NaN  Wtorek Jun 01 04:15:56 +0000 2021
# 2            NaN  Wtorek Jun 01 04:47:19 +0000 2021
# 3            NaN  Wtorek Jun 01 05:47:47 +0000 2021
# 4            NaN  Wtorek Jun 01 05:03:08 +0000 2021
# ...          ...                                ...
# 5098         NaN  Piątek Jun 04 15:44:32 +0000 2021
# 5099         NaN  Piątek Jun 04 15:39:10 +0000 2021
# 5100         NaN  Piątek Jun 04 15:41:51 +0000 2021
# 5101         NaN  Piątek Jun 04 15:42:02 +0000 2021
# 5102         NaN  Piątek Jun 04 15:43:33 +0000 2021
#
#                            hashtags  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4     WspieramyRodziny DzieńDziecka
# ...                             ...
# 5098                            NaN
# 5099                            NaN
# ...

# %%
df["tweet_url"]
# Out:
# 0       https://twitter.com/MarkonMarek/status/1399598...
# 1       https://twitter.com/21lupus/status/13995804479...
# 2       https://twitter.com/WTP_Warszawa/status/139958...
# 3       https://twitter.com/m3_ememem/status/139960356...
# 4       https://twitter.com/j_wisniewska/status/139959...
#                               ...
# 5098    https://twitter.com/tvnwarszawa/status/1400840...
# 5099    https://twitter.com/_MarekP/status/14008395532...
# 5100    https://twitter.com/kulisko/status/14008402275...
# 5101    https://twitter.com/Wojciec24387273/status/140...
# 5102    https://twitter.com/GazetaStoleczna/status/140...
# Name: tweet_url, Length: 5103, dtype: object

# %%
df["urls"]
# Out:
# 0                                                     NaN
# 1                                                     NaN
# 2                                  https://ift.tt/3yTNxU8
# 3                                                     NaN
# 4                                             http://m.in
#                               ...
# 5098    https://tvn24.pl/tvnwarszawa/okolice/warszawa-...
# 5099                                                  NaN
# 5100                                                  NaN
# 5101                                                  NaN
# 5102    https://warszawa.wyborcza.pl/warszawa/7,54420,...
# Name: urls, Length: 5103, dtype: object

# %%
df["media"]
# Out:
# 0       https://twitter.com/MarkonMarek/status/1399598...
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4       https://twitter.com/j_wisniewska/status/139959...
#                               ...
# 5098                                                  NaN
# 5099                                                  NaN
# 5100                                                  NaN
# 5101                                                  NaN
# 5102                                                  NaN
# Name: media, Length: 5103, dtype: object

# %%
# !pip install spacy -U
# !python -m spacy download pl_core_news_sm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 2023-02-09 17:18:44.895195: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.2/20.2 MB 43.9 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('pl_core_news_sm')

# %%
import spacy
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
nlp = spacy.load("pl_core_news_sm")

# %%
nlp.pipeline
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x7fd36392fee0>),
#  ('morphologizer',
#   <spacy.pipeline.morphologizer.Morphologizer at 0x7fd36392fbe0>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x7fd3639ba6d0>),
#  ('lemmatizer',
#   <spacy.pipeline.edit_tree_lemmatizer.EditTreeLemmatizer at 0x7fd36392fa00>),
#  ('tagger', <spacy.pipeline.tagger.Tagger at 0x7fd3639b9b80>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x7fd3639a4140>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x7fd3639ba350>)]

# %%
tekst1 = df["text"]
separator = ' '
tekst2 = separator.join(tekst1)
print(tekst2)
# Out:
# @beata_skwarska Warszawa 😀 https://t.co/W7BcySyuNd Nieznani sprawcy podpalili kapliczkę nadrzewną znajdującą się na warszawskim Grochowie (ul. Podskarbińska w pobliżu ulicy Kobielskiej).  https://t.co/4BjvKx3FlM ⚠️ Utrudnienia w komunikacji: L20 https://t.co/DXAKboKzf5 @LukaszKohut @moanrosa @LincaAgata @jan_jozef_lubos @RafRepRzep @Arnold40146625 @Mateusz_Kubis @wojciech_zo @JozefPorwolDURS @piotrsobik Mówi pan że Warszawa w dialekcie śląskim języka polskiego to Warschau? Aha, naprawdę? Dzieci to największy skarb, o który musimy dbać 👨‍👩‍👧‍👦🐻🍭🍬🍦 #WspieramyRodziny
# ...

# %%
doc = nlp(tekst2)

# %%
for token in doc:
  print(token.is_stop)
# Out:
# Strumieniowane dane wyjściowe obcięte do 5000 ostatnich wierszy.
# False
# True
# False
# False
# True
# False
# False
# False
# False
# False
# False
# True
# False
# True
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# True
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# True
# False
# True
# True
# False
# True
# False
# True
# True
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# True
# True
# False
# True
# True
# True
# False
# True
# False
# False
# False
# True
# True
# True
# False
# False
# False
# True
# False
# False
# False
# True
# False
# False
# False
# False
# True
# False
# False
# True
# True
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# ...

# %%
def remove_stopwords(text):
    doc = nlp(text)
    filtered_sentence = []
    for token in doc:
        if not token.is_stop:
            filtered_sentence.append(token)
    filtered_sentence = [str(token) for token in filtered_sentence]
    filtered_sentence = ' '.join(filtered_sentence)
    return filtered_sentence

df['text_without_stopwords'] = df['text'].apply(remove_stopwords)
df
# Out:
#      coordinates                         created_at  \
# 0            NaN  Wtorek Jun 01 05:26:49 +0000 2021
# 1            NaN  Wtorek Jun 01 04:15:56 +0000 2021
# 2            NaN  Wtorek Jun 01 04:47:19 +0000 2021
# 3            NaN  Wtorek Jun 01 05:47:47 +0000 2021
# 4            NaN  Wtorek Jun 01 05:03:08 +0000 2021
# ...          ...                                ...
# 5098         NaN  Piątek Jun 04 15:44:32 +0000 2021
# 5099         NaN  Piątek Jun 04 15:39:10 +0000 2021
# 5100         NaN  Piątek Jun 04 15:41:51 +0000 2021
# 5101         NaN  Piątek Jun 04 15:42:02 +0000 2021
# 5102         NaN  Piątek Jun 04 15:43:33 +0000 2021
#
#                            hashtags  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4     WspieramyRodziny DzieńDziecka
# ...                             ...
# 5098                            NaN
# 5099                            NaN
# ...

# %%
#Część 2
top_5 = df['favorite_count'].value_counts().head(5)
print(top_5)
# Out:
# 0    3774
# 1     484
# 2     218
# 3      97
# 4      90
# Name: favorite_count, dtype: int64

# %%
top_5 = df['retweet_count'].value_counts().head(5)
print(top_5)
# Out:
# 0      1969
# 1       355
# 381     282
# 2       222
# 3       168
# Name: retweet_count, dtype: int64

# %%
sensitive_tweets = df[df['possibly_sensitive'] == False]

print(sensitive_tweets)
# Out:
#      coordinates                         created_at  \
# 0            NaN  Wtorek Jun 01 05:26:49 +0000 2021
# 2            NaN  Wtorek Jun 01 04:47:19 +0000 2021
# 4            NaN  Wtorek Jun 01 05:03:08 +0000 2021
# 6            NaN  Wtorek Jun 01 05:13:00 +0000 2021
# 8            NaN  Wtorek Jun 01 06:14:26 +0000 2021
# ...          ...                                ...
# 5089         NaN  Piątek Jun 04 15:07:18 +0000 2021
# 5091         NaN  Piątek Jun 04 14:31:56 +0000 2021
# 5097         NaN  Piątek Jun 04 15:38:56 +0000 2021
# 5098         NaN  Piątek Jun 04 15:44:32 +0000 2021
# 5102         NaN  Piątek Jun 04 15:43:33 +0000 2021
#
#                                                hashtags  \
# 0                                                   NaN
# 2                                                   NaN
# 4                         WspieramyRodziny DzieńDziecka
# 6                                                   NaN
# ...

# %%
df['user_created_at'] = pd.to_datetime(df['user_created_at'])

earliest_user = df.groupby(df['user_created_at']).first().reset_index()
earliest_user = earliest_user.loc[earliest_user['user_created_at'] == earliest_user['user_created_at'].min()].iloc[0]

earliest_user_tweets = df[df['user_created_at'] == earliest_user['user_created_at']]

print(earliest_user_tweets)
# Out:
#      coordinates                         created_at hashtags media urls  \
# 1384         NaN  Wtorek Jun 01 20:23:26 +0000 2021      NaN   NaN  NaN
#
#       favorite_count                   id in_reply_to_screen_name  \
# 1384               0  1399823926520393729                     NaN
#
#       in_reply_to_status_id  in_reply_to_user_id  ... user_friends_count  \
# 1384                    NaN                  NaN  ...               1878
#
#      user_listed_count user_location                       user_name  \
# 1384                 4        Polska  Hex 🇵🇱🇺🇦 #ReparationsForPoland
#
#       user_screen_name  user_statuses_count user_time_zone user_urls  \
# 1384             hex24                72484            NaN       NaN
#
#      user_verified                             text_without_stopwords
# 1384         False  Policjanci wydziału walki przestępczością prze...
#
# [1 rows x 36 columns]

# %%
most_followed_user_followers = df['user_followers_count'].max()
most_followed_user_tweets = df[df['user_followers_count'] == most_followed_user_followers]

print(most_followed_user_tweets)
# Out:
#      coordinates                           created_at hashtags media  \
# 92           NaN    Wtorek Jun 01 07:02:05 +0000 2021      NaN   NaN
# 424          NaN    Wtorek Jun 01 09:19:08 +0000 2021      NaN   NaN
# 1008         NaN    Wtorek Jun 01 17:00:13 +0000 2021      NaN   NaN
# 2402         NaN     Środa Jun 02 14:35:15 +0000 2021      NaN   NaN
# 2525         NaN     Środa Jun 02 15:00:28 +0000 2021      NaN   NaN
# 3289         NaN  Czwartek Jun 03 07:34:35 +0000 2021      NaN   NaN
# 3572         NaN  Czwartek Jun 03 11:01:43 +0000 2021      NaN   NaN
#
#                                                    urls  favorite_count  \
# 92    https://tvn24.pl/tvnwarszawa/najnowsze/warszaw...               0
# 424                                                 NaN               0
# 1008  https://tvn24.pl/tvnwarszawa/wola/warszawa-pow...               0
# 2402                                                NaN               0
# ...

# %%
verified_users = df[df['user_verified'] == True]

print(verified_users)
# Out:
#      coordinates                created_at                       hashtags  \
# 4            NaN 2021-06-01 05:03:08+00:00  WspieramyRodziny DzieńDziecka
# 23           NaN 2021-06-01 05:59:11+00:00                            NaN
# 27           NaN 2021-06-04 15:45:39+00:00                            NaN
# 36           NaN 2021-06-01 05:08:26+00:00                   DzieńDziecka
# 49           NaN 2021-06-01 05:16:48+00:00                            NaN
# ...          ...                       ...                            ...
# 4963         NaN 2021-06-04 13:45:25+00:00                            NaN
# 4981         NaN 2021-06-04 14:09:33+00:00                       4czerwca
# 5021         NaN 2021-06-04 15:02:30+00:00                            NaN
# 5036         NaN 2021-06-04 14:27:35+00:00                       4czerwca
# 5098         NaN 2021-06-04 15:44:32+00:00                            NaN
#
#                                                   media  \
# ...

# %%
df['created_at'] = pd.to_datetime(df['created_at'])
df['day_of_week'] = df['created_at'].dt.day_name()

top_1_day = df['day_of_week'].value_counts().head(1)
print(top_1_day)
# Out:
# Wednesday    1657
# Name: day_of_week, dtype: int64

# %%
#Część 3
nlp = spacy.load("en_core_web_sm")
# Out:
# /usr/local/lib/python3.8/dist-packages/spacy/util.py:877: UserWarning: [W095] Model 'en_core_web_sm' (3.4.1) was trained with spaCy v3.4 and may not be 100% compatible with the current version (3.5.0). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
def extract_persons(text):
    doc = nlp(text)
    return [ent.text for ent in doc.ents if ent.label_ == "persName"]

df["persons"] = df["text"].apply(extract_persons)
df
# Out:
#      coordinates                created_at                       hashtags  \
# 0            NaN 2021-06-01 05:26:49+00:00                            NaN
# 1            NaN 2021-06-01 04:15:56+00:00                            NaN
# 2            NaN 2021-06-01 04:47:19+00:00                            NaN
# 3            NaN 2021-06-01 05:47:47+00:00                            NaN
# 4            NaN 2021-06-01 05:03:08+00:00  WspieramyRodziny DzieńDziecka
# ...          ...                       ...                            ...
# 5098         NaN 2021-06-04 15:44:32+00:00                            NaN
# 5099         NaN 2021-06-04 15:39:10+00:00                            NaN
# 5100         NaN 2021-06-04 15:41:51+00:00                            NaN
# 5101         NaN 2021-06-04 15:42:02+00:00                            NaN
# 5102         NaN 2021-06-04 15:43:33+00:00                            NaN
#
#                                                   media  \
# ...

# %%
def extract_places(text):
    doc = nlp(text)
    return [ent.text for ent in doc.ents if ent.label_ == "placeName"]

df["places"] = df["text"].apply(extract_places)
df
# Out:
#      coordinates                created_at                       hashtags  \
# 0            NaN 2021-06-01 05:26:49+00:00                            NaN
# 1            NaN 2021-06-01 04:15:56+00:00                            NaN
# 2            NaN 2021-06-01 04:47:19+00:00                            NaN
# 3            NaN 2021-06-01 05:47:47+00:00                            NaN
# 4            NaN 2021-06-01 05:03:08+00:00  WspieramyRodziny DzieńDziecka
# ...          ...                       ...                            ...
# 5098         NaN 2021-06-04 15:44:32+00:00                            NaN
# 5099         NaN 2021-06-04 15:39:10+00:00                            NaN
# 5100         NaN 2021-06-04 15:41:51+00:00                            NaN
# 5101         NaN 2021-06-04 15:42:02+00:00                            NaN
# 5102         NaN 2021-06-04 15:43:33+00:00                            NaN
#
#                                                   media  \
# ...

# %%
def extract_organizations(text):
    doc = nlp(text)
    return [ent.text for ent in doc.ents if ent.label_ == "orgName"]

df["organizations"] = df["text"].apply(extract_organizations)
df
# Out:
#      coordinates                created_at                       hashtags  \
# 0            NaN 2021-06-01 05:26:49+00:00                            NaN
# 1            NaN 2021-06-01 04:15:56+00:00                            NaN
# 2            NaN 2021-06-01 04:47:19+00:00                            NaN
# 3            NaN 2021-06-01 05:47:47+00:00                            NaN
# 4            NaN 2021-06-01 05:03:08+00:00  WspieramyRodziny DzieńDziecka
# ...          ...                       ...                            ...
# 5098         NaN 2021-06-04 15:44:32+00:00                            NaN
# 5099         NaN 2021-06-04 15:39:10+00:00                            NaN
# 5100         NaN 2021-06-04 15:41:51+00:00                            NaN
# 5101         NaN 2021-06-04 15:42:02+00:00                            NaN
# 5102         NaN 2021-06-04 15:43:33+00:00                            NaN
#
#                                                   media  \
# ...

# %%
#Część 4
import matplotlib.pyplot as plt

df['created_at'] = pd.to_datetime(df['created_at'])
df['day_of_week'] = df['created_at'].dt.day_name()

day_counts = df.groupby('day_of_week')['user_name'].count()

day_counts.plot(kind='bar')
plt.xlabel('Dzień tygodnia')
plt.ylabel('Liczba tweetów')
plt.title('Liczba tweetów względem dni tygodnia')
plt.show()
